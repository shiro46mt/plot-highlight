# %%
# !pip install plot-highlight

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import plot_highlight as phl

# %% [markdown]
# ## scatter plot

# %%
df = sns.load_dataset('tips')

fig, ax = plt.subplots(figsize=(8, 5), dpi=80)
phl.scatterplot(data=df, x='total_bill', y='tip', hue='day', highlights=['Sat', 'Sun'], ax=ax)
fig.set_facecolor('white')
fig.tight_layout()

# %%
# cf. default seaborn plot
df = sns.load_dataset('tips')

fig, ax = plt.subplots(figsize=(8, 5), dpi=80)
sns.scatterplot(data=df, x='total_bill', y='tip', hue='day', ax=ax)
fig.set_facecolor('white')
fig.tight_layout()

# %% [markdown]
# ## lineplot

# %%
df = sns.load_dataset('healthexp')

fig, ax = plt.subplots(figsize=(8, 5), dpi=80)
phl.lineplot(data=df, x='Year', y='Life_Expectancy', hue='Country', highlights=['Japan', 'USA'], ax=ax)
fig.set_facecolor('white')
fig.tight_layout()

# %%
# cf. default seaborn plot
df = sns.load_dataset('healthexp')

fig, ax = plt.subplots(figsize=(8, 5), dpi=80)
sns.lineplot(data=df, x='Year', y='Life_Expectancy', hue='Country', ax=ax)
fig.set_facecolor('white')
fig.tight_layout()

# %% [markdown]
# ## histplot

# %%
df = sns.load_dataset('penguins')

fig, ax = plt.subplots(figsize=(8, 5), dpi=80)
phl.histplot(data=df, x='flipper_length_mm', hue='species', highlights='Adelie', ax=ax)
fig.set_facecolor('white')
fig.tight_layout()
# Out:
# d:\shiro46\plot-highlight\plot_highlight\highlightplot.py:124: UserWarning: Either `bins` or `binwidth` should be set to align bin edges. Setting `bins=10`, but you will likely want to adjust.
#   warnings.warn(msg)

# %%
# cf. default seaborn plot
df = sns.load_dataset('penguins')

fig, ax = plt.subplots(figsize=(8, 5), dpi=80)
sns.histplot(data=df, x='flipper_length_mm', hue='species', ax=ax)
fig.set_facecolor('white')
fig.tight_layout()
